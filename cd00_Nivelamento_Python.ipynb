# %% [markdown]
# # Course: Data Science Course
# # Author: Sandro Camargo <sandrocamargo@unipampa.edu.br>
# # Python Basics
#
# Para abrir o notebook de nivelamento python, [clique aqui](https://github.com/Sandrocamargo/courses/blob/main/FHS/00_Python_Basics.ipynb).
